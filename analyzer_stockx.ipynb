# %% [markdown]
# First, let's import the required libraries and packages

# %%
from google.colab import drive
from pathlib import Path
import glob
import os

#ignore warnings
import warnings
warnings.filterwarnings('ignore')

#import json to view the json data provided
import json

#basic data analysis libraries
import pandas as pd
import numpy as np
from collections import Counter

#visualization libraries
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from wordcloud import WordCloud
import plotly.express as px

#Text Libraries

#NLTK
#!pip install nltk
import nltk
from nltk.corpus import stopwords
from nltk.corpus import wordnet
from nltk import pos_tag
from nltk.tokenize import WhitespaceTokenizer
from nltk.stem import WordNetLemmatizer
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
nltk.download('omw-1.4')

#String
import string
from textblob import TextBlob
import re
import spacy

#sklearn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD

#Gensim
import gensim
from gensim import corpora
# !pip install pyLDAvis==2.1.2
import pyLDAvis
import pyLDAvis.gensim
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/rizkyario/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/rizkyario/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/rizkyario/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Error loading : Package '' not found in index
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/rizkyario/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/rizkyario/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: pyLDAvis==2.1.2 in /usr/local/lib/python3.7/site-packages (2.1.2)
# Requirement already satisfied: joblib>=0.8.4 in /usr/local/lib/python3.7/site-packages (from pyLDAvis==2.1.2) (1.1.0)
# Requirement already satisfied: jinja2>=2.7.2 in /usr/local/lib/python3.7/site-packages (from pyLDAvis==2.1.2) (3.0.3)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.7/site-packages (from pyLDAvis==2.1.2) (2.8.1)
# Requirement already satisfied: funcy in /usr/local/lib/python3.7/site-packages (from pyLDAvis==2.1.2) (1.17)
# Requirement already satisfied: future in /usr/local/lib/python3.7/site-packages (from pyLDAvis==2.1.2) (0.18.2)
# Requirement already satisfied: scipy>=0.18.0 in /usr/local/lib/python3.7/site-packages (from pyLDAvis==2.1.2) (1.7.3)
# Requirement already satisfied: wheel>=0.23.0 in /usr/local/lib/python3.7/site-packages (from pyLDAvis==2.1.2) (0.37.1)
# Requirement already satisfied: pytest in /usr/local/lib/python3.7/site-packages (from pyLDAvis==2.1.2) (7.1.2)
# Requirement already satisfied: pandas>=0.17.0 in /usr/local/lib/python3.7/site-packages (from pyLDAvis==2.1.2) (1.3.5)
# Requirement already satisfied: numpy>=1.9.2 in /usr/local/lib/python3.7/site-packages (from pyLDAvis==2.1.2) (1.21.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.7/site-packages (from jinja2>=2.7.2->pyLDAvis==2.1.2) (2.1.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/site-packages (from pandas>=0.17.0->pyLDAvis==2.1.2) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/site-packages (from pandas>=0.17.0->pyLDAvis==2.1.2) (2020.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/site-packages (from numexpr->pyLDAvis==2.1.2) (21.3)
# Requirement already satisfied: tomli>=1.0.0 in /usr/local/lib/python3.7/site-packages (from pytest->pyLDAvis==2.1.2) (2.0.1)
# Requirement already satisfied: py>=1.8.2 in /usr/local/lib/python3.7/site-packages (from pytest->pyLDAvis==2.1.2) (1.11.0)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.7/site-packages (from pytest->pyLDAvis==2.1.2) (1.1.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /usr/local/lib/python3.7/site-packages (from pytest->pyLDAvis==2.1.2) (1.0.0)
# Requirement already satisfied: importlib-metadata>=0.12 in /usr/local/lib/python3.7/site-packages (from pytest->pyLDAvis==2.1.2) (3.4.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.7/site-packages (from pytest->pyLDAvis==2.1.2) (21.4.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/site-packages (from importlib-metadata>=0.12->pytest->pyLDAvis==2.1.2) (3.7.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/site-packages (from importlib-metadata>=0.12->pytest->pyLDAvis==2.1.2) (3.10.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas>=0.17.0->pyLDAvis==2.1.2) (1.12.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/site-packages (from packaging->numexpr->pyLDAvis==2.1.2) (3.0.7)
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621

# %% [markdown]
# Opening the JSON file using the json library

# %%
web='stockx'
# Opening the JSON file
json_dir = './data/stockx'

json_pattern = os.path.join(json_dir, '*.json')
file_list = glob.glob(json_pattern)

dfs = []
for file in file_list:
    with open(file) as f:
        json_data = pd.json_normalize(json.loads(f.read()))
        json_data['site'] = file.rsplit("/", 1)[-1]
    dfs.append(json_data)
df = pd.concat(dfs)
print(len(df))
# Out:
# 1999

# %% [markdown]
# Opening the JSON data using Pandas

# %%
#Using Pandas

json_pattern = os.path.join(json_dir, '*.json')
file_list = glob.glob(json_pattern)

dfs = []
for file in file_list:
    with open(file) as f:
        json_data = pd.json_normalize(json.loads(f.read()))
        json_data['site'] = file.rsplit("/", 1)[-1]
    dfs.append(json_data)
reviewsDF = pd.concat(dfs)
reviewsDF.head(10)
# Out:
#          date            author  \
# 0  2022-04-28             Craig
# 1  2022-04-28            Sharaf
# 2  2022-04-28          Marcos A
# 3  2022-04-29           Charles
# 4  2022-04-29             Cuban
# 5  2022-04-29           kamilah
# 6  2022-04-29           Phantom
# 7  2022-04-29            Kavone
# 8  2022-04-29           Michael
# 9  2022-04-29  Peter Ian Staker
#
#                                                 text  \
# 0  I placed a bid/order then did not hear anythin...
# 1                                 Delivery the worst
# 2  Not helpful at all. Website goes around in cir...
# 3  You sold me some fake ass shoes and tried tell...
# 4  I still haven’t received anything from stock x...
# 5  I ordered the shoes and it took forever to get...
# 6  You should be able to cancel within the first ...
# 7  The shipping took forever, ups doesn't conduct...
# 8  I ordered a pair of shoes off of stock x, they...
# 9  its f2cking late by idk know how many days bec...
#
#                                                title  stars location  \
# 0            I placed a bid/order then did not hear…      1       US
# 1                                 Delivery the worst      1       US
# 2                                 Not helpful at all      1       US
# 3               You sold me some fake ass shoes and…      1       US
# 4                                         No package      1       US
# 5           I ordered the shoes and it took forever…      1       US
# 6           You should be able to cancel within the…      3       US
# 7                          The shipping took forever      3       US
# 8  I ordered a pair of shoes off of stockx and ne...      1       US
# 9                                               SH2T      1       AU
#
#                                                  url             site
# 0  https://www.trustpilot.com/review/stockx.com?p...  reviews_15.json
# 1  https://www.trustpilot.com/review/stockx.com?p...  reviews_15.json
# 2  https://www.trustpilot.com/review/stockx.com?p...  reviews_15.json
# 3  https://www.trustpilot.com/review/stockx.com?p...  reviews_15.json
# 4  https://www.trustpilot.com/review/stockx.com?p...  reviews_15.json
# 5  https://www.trustpilot.com/review/stockx.com?p...  reviews_15.json
# 6  https://www.trustpilot.com/review/stockx.com?p...  reviews_15.json
# 7  https://www.trustpilot.com/review/stockx.com?p...  reviews_15.json
# 8  https://www.trustpilot.com/review/stockx.com?p...  reviews_15.json
# 9  https://www.trustpilot.com/review/stockx.com?p...  reviews_15.json

# %% [markdown]
# # **Data Cleaning**

# %% [markdown]
# Round 1 of cleaning:
#
# - Converting the text to Lowercase
#
# - Removing text in brackets
#
# - Removing punctuation and words

# %%
#Round 1 of cleaning
def clean_text(text):
    # converting to lower
    text = text.lower() 
    #remove text in square brackets
    text = re.sub('\[.*?\]','',text)
    #remove punctuation and remove words
    text = re.sub('[%s]' % re.escape(string.punctuation),'',text)
    text = re.sub('\w*\d\w*','',text)
    return text

# %%
reviewsDF.title = reviewsDF.title.apply(clean_text)
reviewsDF.text = reviewsDF.text.apply(clean_text)
reviewsDF.head()
# Out:
#          date    author                                               text  \
# 0  2022-04-28     Craig  i placed a bidorder then did not hear anything...
# 1  2022-04-28    Sharaf                                 delivery the worst
# 2  2022-04-28  Marcos A  not helpful at all website goes around in circ...
# 3  2022-04-29   Charles  you sold me some fake ass shoes and tried tell...
# 4  2022-04-29     Cuban  i still haven’t received anything from stock x...
#
#                                     title  stars location  \
# 0  i placed a bidorder then did not hear…      1       US
# 1                      delivery the worst      1       US
# 2                      not helpful at all      1       US
# 3    you sold me some fake ass shoes and…      1       US
# 4                              no package      1       US
#
#                                                  url             site
# 0  https://www.trustpilot.com/review/stockx.com?p...  reviews_15.json
# 1  https://www.trustpilot.com/review/stockx.com?p...  reviews_15.json
# 2  https://www.trustpilot.com/review/stockx.com?p...  reviews_15.json
# 3  https://www.trustpilot.com/review/stockx.com?p...  reviews_15.json
# 4  https://www.trustpilot.com/review/stockx.com?p...  reviews_15.json

# %% [markdown]
# Round 2 of Cleaning:
#
# - Removing additional punctuation
#
# - Removing non-sensical text

# %%
#Round 2 of cleaning
def clean_text2(text):
    '''get rid of some additional punctuation and non-sesical text that was missed the first time'''
    text = re.sub('[''""...]','',text)
    text = re.sub('\n','',text)
    return text

# %%
reviewsDF.title = reviewsDF.title.apply(clean_text2)
reviewsDF.text = reviewsDF.text.apply(clean_text2)
reviewsDF.head()
# Out:
#          date    author                                               text  \
# 0  2022-04-28     Craig  i placed a bidorder then did not hear anything...
# 1  2022-04-28    Sharaf                                 delivery the worst
# 2  2022-04-28  Marcos A  not helpful at all website goes around in circ...
# 3  2022-04-29   Charles  you sold me some fake ass shoes and tried tell...
# 4  2022-04-29     Cuban  i still haven’t received anything from stock x...
#
#                                     title  stars location  \
# 0  i placed a bidorder then did not hear…      1       US
# 1                      delivery the worst      1       US
# 2                      not helpful at all      1       US
# 3    you sold me some fake ass shoes and…      1       US
# 4                              no package      1       US
#
#                                                  url             site
# 0  https://www.trustpilot.com/review/stockx.com?p...  reviews_15.json
# 1  https://www.trustpilot.com/review/stockx.com?p...  reviews_15.json
# 2  https://www.trustpilot.com/review/stockx.com?p...  reviews_15.json
# 3  https://www.trustpilot.com/review/stockx.com?p...  reviews_15.json
# 4  https://www.trustpilot.com/review/stockx.com?p...  reviews_15.json

# %% [markdown]
# Round 3 of Cleaning:
#
# - Punctuation
#
# - Words containing numbers
#
# - Stopwords
#
# - Empty tokens
#
# - Part of Speech Tagging
#
# - Lemmatization
#
# - Removing one letter words

# %%
#Round 3 of cleaning (postag, stopwords removal and lemmatization etc)
def get_wordnet_pos(word):
    #Map POS tag to first letter
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}

    return tag_dict.get(tag, wordnet.NOUN)
    
def clean_text3(text):
    #tokenizing removing puncutation
    text = [word.strip(string.punctuation) for word in text.split(" ")]
    #removing words containing numbers
    text = [word for word in text if not any(c.isdigit() for c in word)]
    #removing stopwords
    stop = stopwords.words('english')
    text = [x for x in text if x not in stop]
    #removing empty tokens
    text = [t for t in text if len(t) > 0]
    #part of speech tagging
    pos_tags = pos_tag(text)
    #lemmatizing text
    text = [WordNetLemmatizer().lemmatize(t[0], get_wordnet_pos(t[1])) for t in pos_tags]
    #removing one letter words
    text = [t for t in text if len(t) > 1]
    #joining
    text = " ".join(text)
    return(text)

# %%
reviewsDF.title = reviewsDF.title.apply(clean_text3)
reviewsDF.text = reviewsDF.text.apply(clean_text3)
reviewsDF.head()
# Out:
#          date    author                                               text  \
# 0  2022-04-28     Craig  placed bidorder hear anything week found item ...
# 1  2022-04-28    Sharaf                                     delivery worst
# 2  2022-04-28  Marcos A  helpful website go around circle looking link ...
# 3  2022-04-29   Charles  sold fake as shoe tried telling would pas dead...
# 4  2022-04-29     Cuban  still haven’t received anything stock order pu...
#
#                     title  stars location  \
# 0   placed bidorder hear…      1       US
# 1          delivery worst      1       US
# 2                 helpful      1       US
# 3  sold fake as shoe and…      1       US
# 4                 package      1       US
#
#                                                  url             site
# 0  https://www.trustpilot.com/review/stockx.com?p...  reviews_15.json
# 1  https://www.trustpilot.com/review/stockx.com?p...  reviews_15.json
# 2  https://www.trustpilot.com/review/stockx.com?p...  reviews_15.json
# 3  https://www.trustpilot.com/review/stockx.com?p...  reviews_15.json
# 4  https://www.trustpilot.com/review/stockx.com?p...  reviews_15.json

# %% [markdown]
# Save the Cleaned data for easy later use

# %%
#Pickling the DF for later use
reviewsDF.to_pickle(web+".pkl")

# %% [markdown]
# # **Feature Engineering**

# %% [markdown]
# Adding new columns for
# 1. Length
# 2. Word Count
# 3. Polarity
# 4. Sentiment
# 5. Rating
# 6. Website

# %%
#Let's add a column length, which indicates the length of each text
reviewsDF['length'] = reviewsDF['text'].apply(len)
#Adding a column numOfWords which indicates the number of words in the text
reviewsDF['numOfWords'] = reviewsDF['text'].apply(lambda x: len(x.split(" ")))
#Adding a Polarity column - using TextBlob
reviewsDF['polarity'] = reviewsDF['text'].map(lambda text: TextBlob(text).sentiment.polarity)
#Adding Sentiment Intensity column - using SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()
reviewsDF["sentiments"] = reviewsDF["text"].apply(lambda x: sid.polarity_scores(x))
reviewsDF = pd.concat([reviewsDF.drop(['sentiments'], axis=1), reviewsDF['sentiments'].apply(pd.Series)], axis=1)
reviewsDF.head()
# Out:
#          date    author                                               text  \
# 0  2022-04-28     Craig  placed bidorder hear anything week found item ...
# 1  2022-04-28    Sharaf                                     delivery worst
# 2  2022-04-28  Marcos A  helpful website go around circle looking link ...
# 3  2022-04-29   Charles  sold fake as shoe tried telling would pas dead...
# 4  2022-04-29     Cuban  still haven’t received anything stock order pu...
#
#                     title  stars location  \
# 0   placed bidorder hear…      1       US
# 1          delivery worst      1       US
# 2                 helpful      1       US
# 3  sold fake as shoe and…      1       US
# 4                 package      1       US
#
#                                                  url             site  length  \
# 0  https://www.trustpilot.com/review/stockx.com?p...  reviews_15.json     159
# 1  https://www.trustpilot.com/review/stockx.com?p...  reviews_15.json      14
# 2  https://www.trustpilot.com/review/stockx.com?p...  reviews_15.json     114
# 3  https://www.trustpilot.com/review/stockx.com?p...  reviews_15.json      72
# 4  https://www.trustpilot.com/review/stockx.com?p...  reviews_15.json      64
#
#    numOfWords  polarity    neg    neu    pos  compound
# 0          21  0.000000  0.205  0.795  0.000   -0.5994
# 1           2 -1.000000  0.804  0.196  0.000   -0.6249
# 2          18 -0.000379  0.105  0.762  0.133    0.1531
# 3          12 -0.500000  0.220  0.780  0.000   -0.4767
# 4          10  0.000000  0.000  1.000  0.000    0.0000

# %%
#Adding a Sentiment column depending on the calculated compound score
reviewsDF['Sentiment'] = reviewsDF['compound'].apply(lambda c: 'pos' if c >=0 else 'neg')
reviewsDF.Sentiment.value_counts()
# Out:
# pos    1065
# neg     934
# Name: Sentiment, dtype: int64

# %%
#Adding a column (numeric) for rating
#reviewsDF.stars.value_counts()
reviewsDF['rating'] = reviewsDF['stars']
reviewsDF.head()
# Out:
#          date    author                                               text  \
# 0  2022-04-28     Craig  placed bidorder hear anything week found item ...
# 1  2022-04-28    Sharaf                                     delivery worst
# 2  2022-04-28  Marcos A  helpful website go around circle looking link ...
# 3  2022-04-29   Charles  sold fake as shoe tried telling would pas dead...
# 4  2022-04-29     Cuban  still haven’t received anything stock order pu...
#
#                     title  stars location  \
# 0   placed bidorder hear…      1       US
# 1          delivery worst      1       US
# 2                 helpful      1       US
# 3  sold fake as shoe and…      1       US
# 4                 package      1       US
#
#                                                  url             site  length  \
# 0  https://www.trustpilot.com/review/stockx.com?p...  reviews_15.json     159
# 1  https://www.trustpilot.com/review/stockx.com?p...  reviews_15.json      14
# 2  https://www.trustpilot.com/review/stockx.com?p...  reviews_15.json     114
# 3  https://www.trustpilot.com/review/stockx.com?p...  reviews_15.json      72
# 4  https://www.trustpilot.com/review/stockx.com?p...  reviews_15.json      64
#
#    numOfWords  polarity    neg    neu    pos  compound Sentiment  rating
# 0          21  0.000000  0.205  0.795  0.000   -0.5994       neg       1
# 1           2 -1.000000  0.804  0.196  0.000   -0.6249       neg       1
# 2          18 -0.000379  0.105  0.762  0.133    0.1531       pos       1
# 3          12 -0.500000  0.220  0.780  0.000   -0.4767       neg       1
# 4          10  0.000000  0.000  1.000  0.000    0.0000       pos       1

# %%
#Analyzing URL column
reviewsDF.url.str.split("review/")[0]
reviewsDF['Site'] = reviewsDF.url.apply(lambda x: x.split("review/")[1])
reviewsDF.head()
# Out:
#          date    author                                               text  \
# 0  2022-04-28     Craig  placed bidorder hear anything week found item ...
# 1  2022-04-28    Sharaf                                     delivery worst
# 2  2022-04-28  Marcos A  helpful website go around circle looking link ...
# 3  2022-04-29   Charles  sold fake as shoe tried telling would pas dead...
# 4  2022-04-29     Cuban  still haven’t received anything stock order pu...
#
#                     title  stars location  \
# 0   placed bidorder hear…      1       US
# 1          delivery worst      1       US
# 2                 helpful      1       US
# 3  sold fake as shoe and…      1       US
# 4                 package      1       US
#
#                                                  url             site  length  \
# 0  https://www.trustpilot.com/review/stockx.com?p...  reviews_15.json     159
# 1  https://www.trustpilot.com/review/stockx.com?p...  reviews_15.json      14
# 2  https://www.trustpilot.com/review/stockx.com?p...  reviews_15.json     114
# 3  https://www.trustpilot.com/review/stockx.com?p...  reviews_15.json      72
# 4  https://www.trustpilot.com/review/stockx.com?p...  reviews_15.json      64
#
#    numOfWords  polarity    neg    neu    pos  compound Sentiment  rating  \
# 0          21  0.000000  0.205  0.795  0.000   -0.5994       neg       1
# 1           2 -1.000000  0.804  0.196  0.000   -0.6249       neg       1
# 2          18 -0.000379  0.105  0.762  0.133    0.1531       pos       1
# 3          12 -0.500000  0.220  0.780  0.000   -0.4767       neg       1
# 4          10  0.000000  0.000  1.000  0.000    0.0000       pos       1
#
#                                          Site
# 0  stockx.com?page=15&stars=1&stars=2&stars=3
# 1  stockx.com?page=15&stars=1&stars=2&stars=3
# 2  stockx.com?page=15&stars=1&stars=2&stars=3
# 3  stockx.com?page=15&stars=1&stars=2&stars=3
# 4  stockx.com?page=15&stars=1&stars=2&stars=3

# %%
reviewsDF.Site.value_counts()
# Out:
# stockx.com?page=15&stars=1&stars=2&stars=3    20
# stockx.com?page=11&stars=1&stars=2&stars=3    20
# stockx.com?page=67&stars=1&stars=2&stars=3    20
# stockx.com?page=30&stars=1&stars=2&stars=3    20
# stockx.com?page=26&stars=1&stars=2&stars=3    20
#                                               ..
# stockx.com?page=25&stars=1&stars=2&stars=3    20
# stockx.com?page=72&stars=1&stars=2&stars=3    20
# stockx.com?page=48&stars=1&stars=2&stars=3    20
# stockx.com?page=82&stars=1&stars=2&stars=3    20
# stockx.com?page=75&stars=1&stars=2&stars=3    19
# Name: Site, Length: 100, dtype: int64

# %% [markdown]
# # **EDA**

# %% [markdown]
# Exploratory Data Analysis

# %%
#This function is used to see mathematical metrics of all the columns 
reviewsDF.describe()
# Out:
#              stars       length   numOfWords     polarity          neg  \
# count  1999.000000  1999.000000  1999.000000  1999.000000  1999.000000
# mean      1.456728   171.669335    25.662331    -0.033258     0.151944
# std       0.806631   216.181768    31.850259     0.287590     0.166645
# min       1.000000     0.000000     1.000000    -1.000000     0.000000
# 25%       1.000000    47.500000     7.000000    -0.130722     0.000000
# 50%       1.000000   104.000000    16.000000     0.000000     0.120000
# 75%       2.000000   212.000000    32.000000     0.100000     0.226000
# max       5.000000  3047.000000   465.000000     1.000000     1.000000
#
#                neu          pos     compound       rating
# count  1999.000000  1999.000000  1999.000000  1999.000000
# mean      0.740132     0.107426    -0.080629     1.456728
# std       0.192301     0.136237     0.487218     0.806631
# min       0.000000     0.000000    -0.990300     1.000000
# 25%       0.623000     0.000000    -0.476700     1.000000
# 50%       0.741000     0.071000     0.000000     1.000000
# 75%       0.881000     0.172000     0.273200     2.000000
# max       1.000000     1.000000     0.985400     5.000000

# %%
#To see the type of each column and check if there are any null values 
reviewsDF.date = pd.to_datetime(reviewsDF['date'])
reviewsDF = reviewsDF[reviewsDF.stars < 4]
reviewsDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1982 entries, 0 to 19
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1982 non-null   datetime64[ns]
#  1   author      1982 non-null   object
#  2   text        1982 non-null   object
#  3   title       1982 non-null   object
#  4   stars       1982 non-null   int64
#  5   location    1982 non-null   object
#  6   url         1982 non-null   object
#  7   site        1982 non-null   object
#  8   length      1982 non-null   int64
#  9   numOfWords  1982 non-null   int64
#  10  polarity    1982 non-null   float64
#  11  neg         1982 non-null   float64
#  12  neu         1982 non-null   float64
#  13  pos         1982 non-null   float64
#  14  compound    1982 non-null   float64
#  15  Sentiment   1982 non-null   object
#  16  rating      1982 non-null   int64
#  17  Site        1982 non-null   object
# dtypes: datetime64[ns](1), float64(5), int64(4), object(8)
# memory usage: 294.2+ KB

# %%
#To count number of samples for each rating
reviewsDF.rating.value_counts()
# Out:
# 1    1439
# 3     303
# 2     240
# Name: rating, dtype: int64

# %%
# Review length distribution
reviewsDF['length'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
#Histogram plot to see the lenght of each rating
reviewsDF.hist(column = 'length', by = 'rating')
# Out:
# array([[<AxesSubplot:title={'center':'1'}>,
#         <AxesSubplot:title={'center':'2'}>],
#        [<AxesSubplot:title={'center':'3'}>, <AxesSubplot:>]], dtype=object)

# %%
#Histogram plot to analyze number of reviews with respect to date
#As we can see, 2018 has many reviews comapared to other years
fig = px.histogram(reviewsDF, x='date', title='Reviews by date')
fig.update_xaxes(categoryorder='category descending', title='Date').update_yaxes(title='Number of reviews')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.11.1.min.js"></script>                <div id="ca1bc496-f8e4-462d-bfd4-e413488bfc97" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ca1bc496-f8e4-462d-bfd4-e413488bfc97")) {                    Plotly.newPlot(                        "ca1bc496-f8e4-462d-bfd4-e413488bfc97",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"date=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["2022-04-28T00:00:00","2022-04-28T00:00:00","2022-04-28T00:00:00","2022-04-29T00:00:00","2022-04-29T00:00:00","2022-04-29T00:00:00","2022-04-29T00:00:00","2022-04-29T00:00:00","2022-04-29T00:00:00","2022-04-29T00:00:00","2022-04-29T00:00:00","2022-04-29T00:00:00","2022-04-29T00:00:00","2022-04-29T00:00:00","2022-04-29T00:00:00","2022-04-29T00:00:00","2022-04-29T00:00:00","2022-04-29T00:00:00","2022-04-29T00:00:00","2022-04-29T00:00:00","2022-05-03T00:00:00","2022-05-03T00:00:00","2022-05-03T00:00:00","2022-05-03T00:00:00","2022-05-03T00:00:00","2022-05-03T00:00:00","2022-05-04T00:00:00","2022-05-04T00:00:00","2022-05-04T00:00:00","2022-05-04T00:00:00","2022-05-04T00:00:00","2022-05-04T00:00:00","2022-05-04T00:00:00","2022-05-04T00:00:00","2022-05-04T00:00:00","2022-05-04T00:00:00","2022-05-04T00:00:00","2022-05-04T00:00:00","2022-05-04T00:00:00","2022-05-04T00:00:00","2022-04-11T00:00:00","2022-04-11T00:00:00","2022-04-11T00:00:00","2022-04-11T00:00:00","2022-04-11T00:00:00","2022-04-11T00:00:00","2022-04-11T00:00:00","2022-04-11T00:00:00","2022-04-11T00:00:00","2022-04-11T00:00:00","2022-04-11T00:00:00","2022-04-11T00:00:00","2022-04-11T00:00:00","2022-04-11T00:00:00","2022-04-11T00:00:00","2022-04-11T00:00:00","2022-04-11T00:00:00","2022-04-11T00:00:00","2022-04-11T00:00:00","2022-04-11T00:00:00","2022-04-03T00:00:00","2022-04-03T00:00:00","2022-04-03T00:00:00","2022-04-03T00:00:00","2022-04-03T00:00:00","2022-04-03T00:00:00","2022-04-03T00:00:00","2022-04-03T00:00:00","2022-04-03T00:00:00","2022-04-03T00:00:00","2022-04-03T00:00:00","2022-04-03T00:00:00","2022-04-03T00:00:00","2022-04-03T00:00:00","2022-04-03T00:00:00","2022-04-03T00:00:00","2022-04-03T00:00:00","2022-04-03T00:00:00","2022-04-03T00:00:00","2022-04-03T00:00:00","2021-11-05T00:00:00","2021-11-05T00:00:00","2021-11-05T00:00:00","2021-11-05T00:00:00","2021-11-05T00:00:00","2021-11-05T00:00:00","2021-11-05T00:00:00","2021-11-05T00:00:00","2021-11-05T00:00:00","2021-11-05T00:00:00","2021-11-05T00:00:00","2021-11-05T00:00:00","2021-11-05T00:00:00","2021-11-06T00:00:00","2021-11-06T00:00:00","2021-11-06T00:00:00","2021-11-06T00:00:00","2021-11-06T00:00:00","2021-11-08T00:00:00","2021-11-09T00:00:00","2022-02-14T00:00:00","2022-02-14T00:00:00","2022-02-15T00:00:00","2022-02-15T00:00:00","2022-02-16T00:00:00","2022-02-17T00:00:00","2022-02-17T00:00:00","2022-02-17T00:00:00","2022-02-18T00:00:00","2022-02-18T00:00:00","2022-02-18T00:00:00","2022-02-18T00:00:00","2022-02-19T00:00:00","2022-02-19T00:00:00","2022-02-20T00:00:00","2022-02-20T00:00:00","2022-02-21T00:00:00","2022-02-21T00:00:00","2022-02-22T00:00:00","2022-02-22T00:00:00","2022-04-13T00:00:00","2022-04-13T00:00:00","2022-04-13T00:00:00","2022-04-13T00:00:00","2022-04-13T00:00:00","2022-04-13T00:00:00","2022-04-13T00:00:00","2022-04-13T00:00:00","2022-04-13T00:00:00","2022-04-13T00:00:00","2022-04-13T00:00:00","2022-04-13T00:00:00","2022-04-13T00:00:00","2022-04-13T00:00:00","2022-04-13T00:00:00","2022-04-13T00:00:00","2022-04-13T00:00:00","2022-04-13T00:00:00","2022-04-13T00:00:00","2022-04-13T00:00:00","2022-01-18T00:00:00","2022-01-18T00:00:00","2022-01-18T00:00:00","2022-01-19T00:00:00","2022-01-20T00:00:00","2022-01-20T00:00:00","2022 ...

# %%
#Histogram plot to analyze number of reviews with respect to date and ratings
#As we can see there are many one star ratings compared to all other ratings 
fig = px.histogram(reviewsDF, x='date',  title='Reviews by date', color='rating', nbins=10, log_y=True, barmode='group')
fig.update_xaxes(categoryorder='category descending', title='Date').update_yaxes(title='Number of reviews')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.11.1.min.js"></script>                <div id="edf67961-6c6a-4a2f-85c7-a0568bd5ff29" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("edf67961-6c6a-4a2f-85c7-a0568bd5ff29")) {                    Plotly.newPlot(                        "edf67961-6c6a-4a2f-85c7-a0568bd5ff29",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"rating=1<br>date=%{x}<br>count=%{y}<extra></extra>","legendgroup":"1","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"1","nbinsx":10,"offsetgroup":"1","orientation":"v","showlegend":true,"x":["2022-04-28T00:00:00","2022-04-28T00:00:00","2022-04-28T00:00:00","2022-04-29T00:00:00","2022-04-29T00:00:00","2022-04-29T00:00:00","2022-04-29T00:00:00","2022-04-29T00:00:00","2022-04-29T00:00:00","2022-04-29T00:00:00","2022-04-29T00:00:00","2022-04-29T00:00:00","2022-04-29T00:00:00","2022-04-29T00:00:00","2022-05-03T00:00:00","2022-05-03T00:00:00","2022-05-03T00:00:00","2022-05-03T00:00:00","2022-05-03T00:00:00","2022-05-04T00:00:00","2022-05-04T00:00:00","2022-05-04T00:00:00","2022-05-04T00:00:00","2022-05-04T00:00:00","2022-05-04T00:00:00","2022-05-04T00:00:00","2022-04-11T00:00:00","2022-04-11T00:00:00","2022-04-11T00:00:00","2022-04-11T00:00:00","2022-04-11T00:00:00","2022-04-11T00:00:00","2022-04-11T00:00:00","2022-04-11T00:00:00","2022-04-11T00:00:00","2022-04-11T00:00:00","2022-04-11T00:00:00","2022-04-11T00:00:00","2022-04-03T00:00:00","2022-04-03T00:00:00","2022-04-03T00:00:00","2022-04-03T00:00:00","2022-04-03T00:00:00","2022-04-03T00:00:00","2022-04-03T00:00:00","2022-04-03T00:00:00","2022-04-03T00:00:00","2022-04-03T00:00:00","2022-04-03T00:00:00","2022-04-03T00:00:00","2022-04-03T00:00:00","2022-04-03T00:00:00","2022-04-03T00:00:00","2022-04-03T00:00:00","2021-11-05T00:00:00","2021-11-05T00:00:00","2021-11-05T00:00:00","2021-11-05T00:00:00","2021-11-05T00:00:00","2021-11-06T00:00:00","2021-11-06T00:00:00","2021-11-06T00:00:00","2021-11-06T00:00:00","2021-11-09T00:00:00","2022-02-14T00:00:00","2022-02-14T00:00:00","2022-02-15T00:00:00","2022-02-15T00:00:00","2022-02-16T00:00:00","2022-02-17T00:00:00","2022-02-17T00:00:00","2022-02-17T00:00:00","2022-02-18T00:00:00","2022-02-18T00:00:00","2022-02-18T00:00:00","2022-02-18T00:00:00","2022-02-19T00:00:00","2022-02-19T00:00:00","2022-02-20T00:00:00","2022-02-20T00:00:00","2022-02-21T00:00:00","2022-02-21T00:00:00","2022-02-22T00:00:00","2022-02-22T00:00:00","2022-04-13T00:00:00","2022-04-13T00:00:00","2022-04-13T00:00:00","2022-04-13T00:00:00","2022-04-13T00:00:00","2022-04-13T00:00:00","2022-04-13T00:00:00","2022-04-13T00:00:00","2022-04-13T00:00:00","2022-04-13T00:00:00","2022-04-13T00:00:00","2022-04-13T00:00:00","2022-04-13T00:00:00","2022-04-13T00:00:00","2022-01-18T00:00:00","2022-01-18T00:00:00","2022-01-18T00:00:00","2022-01-20T00:00:00","2022-01-20T00:00:00","2022-01-20T00:00:00","2022-01-21T00:00:00","2022-01-21T00:00:00","2022-01-21T00:00:00","2022-01-21T00:00:00","2022-01-22T00:00:00","2022-01-23T00:00:00","2022-01-23T00:00:00","2022-01-24T00:00:00","2022-01-25T00:00:00","2022-01-25T00:00:00","2022-01-26T00:00:00","2022-01-27T00:00:00","2022-04-26T00:00:00","2022-04-26T00:00:00","2022-04-27T00:00:00","2022-04-27T00:00:00","2022-04-27T00:00:00","2022-04-27T00:00:00","2022-04-27T00:00:00","2022-04-27T00:00:00","2022-04-27T00:00:00","2022-04-27T00:00:00","2022-04-27T00:00:00","2022-04-27T00:00:00","2022-04-27T00:00:00","2022-03-31T00:00:00","2022-03-31T00:00:00","2022-03-31T00:00:00","2022-03-31T00:00:00","2022-03-31T00:00:00","2022-03-31T00:00:00","2022-03-31T00:00:00","2022-03-31T00:00:00","2022-03-31T00:00:00","2022-04-01T00:00:00","2022-04-01T00:00:00","2022-04-01T00:00:00","2022-04-01T00:00:00","2022-03-17T00:00:00","2022-03-17T00:00:00","2022-03-17T00:00:00"," ...

# %%
#Histogram plot for polarity, and by observing we say that there are many reviwes with the polarity between 0 to 0.25
reviewsDF.polarity.hist()
# Out:
# <AxesSubplot:>

# %%
#Plot to analyze number of words
reviewsDF['numOfWords'].hist()
# Out:
# <AxesSubplot:>

# %%
#top positive reviews
reviewsDF.sort_values("pos", ascending = False)[["text", "pos", "neg", "stars"]].head(20)
# Out:
#                                                  text    pos  neg  stars
# 3                                                good  1.000  0.0      1
# 14                                             ok wow  1.000  0.0      2
# 7                                       may great fan  0.865  0.0      2
# 9                              authentication amazing  0.792  0.0      1
# 6                                 packaging trustable  0.767  0.0      3
# 14                                       good morning  0.744  0.0      3
# 7                                           size good  0.744  0.0      2
# 19                                      shoelace good  0.744  0.0      3
# 10                                        take profit  0.744  0.0      1
# 9     pretty great shipping take time everything good  0.718  0.0      3
# 13                              good want full refund  0.677  0.0      1
# 14                                      okay whatever  0.655  0.0      1
# 17                        good support stole one shoe  0.651  0.0      1
# 12  loved shoe perfect material match everything g...  0.641  0.0      1
# 2   say im perfectly satisfied customer would reco...  0.639  0.0      3
# 2                                  quality isn’t good  0.592  0.0      1
# 0                                   high good company  0.592  0.0      3
# 10                               good shipping update  0.592  0.0      3
# 12  like service would great currency displayed cl...  0.571  0.0      3
# 3   need better return policy place well better wa...  0.568  0.0      3

# %%
#Analyzing the negative data - ascending order 
reviewsDF.sort_values("neg", ascending = False)[["text", "pos", "neg", "stars"]].head(20)
# Out:
#                       text  pos    neg  stars
# 12                 charged  0.0  1.000      1
# 4             disappointed  0.0  1.000      1
# 17       fake product scam  0.0  0.872      1
# 1           delivery worst  0.0  0.804      1
# 14           worst website  0.0  0.804      1
# 7                 scam buy  0.0  0.787      1
# 9           scam basically  0.0  0.787      1
# 10            bad business  0.0  0.778      1
# 1   chicago mids fake scam  0.0  0.773      1
# 0         disgusting order  0.0  0.773      1
# 17           shoe rejected  0.0  0.767      1
# 18            lateso angry  0.0  0.767      1
# 11             lace broken  0.0  0.756      2
# 5             poor service  0.0  0.756      2
# 2               think fake  0.0  0.756      1
# 0               wrong size  0.0  0.756      1
# 6             product fake  0.0  0.756      1
# 2             item damaged  0.0  0.744      3
# 15                guy suck  0.0  0.744      1
# 4        snicker defective  0.0  0.744      1

# %%
# reviewsDF['length'][1234]

# %%
#WordCloud of text in the complete data set
from wordcloud import STOPWORDS

stopwords = ['item', 'vc', 'vestiaire', 'm', 'ive'] + list(STOPWORDS)

text = " ".join(i for i in reviewsDF.text)
wordcloud = WordCloud(stopwords = stopwords, width=800, height=400).generate(text)
fig = plt.figure(1, figsize = (20, 20))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %%
#Percentage of each word in the wordcloud
wordcloud.words_
# Out:
# {'shoe': 1.0,
#  'stockx': 0.7296767874632712,
#  'order': 0.4632713026444662,
#  'company': 0.2683643486777669,
#  's': 0.2654260528893242,
#  'stock': 0.2605288932419197,
#  'one': 0.24877571008814886,
#  'day': 0.24191968658178256,
#  'customer service': 0.22233104799216455,
#  'ordered': 0.21449559255631734,
#  'got': 0.21253672869735554,
#  'never': 0.20861900097943192,
#  'purchase': 0.20176297747306562,
#  'sent': 0.2007835455435847,
#  'time': 0.197845249755142,
#  'email': 0.1958863858961802,
#  'money': 0.1929480901077375,
#  'product': 0.1831537708129285,
#  'refund': 0.1831537708129285,
#  'still': 0.1802154750244858,
#  'back': 0.1743388834476004,
#  'received': 0.17042115572967678,
#  'buy': 0.16748285994123407,
#  'box': 0.16748285994123407,
#  'said': 0.16356513222331048,
#  'fake': 0.16062683643486778,
#  'even': 0.16062683643486778,
#  'seller': 0.15768854064642507,
#  'shipping': 0.15572967678746327,
#  'don t': 0.14691478942213515,
#  'sneaker': 0.14593535749265427,
#  'week': 0.14495592556317335,
#  'price': 0.14397649363369247,
#  'bought': 0.14005876591576885,
#  'return': 0.13907933398628794,
#  'dont': 0.13614103819784526,
#  'size': 0.13418217433888344,
#  'site': 0.13320274240940255,
#  'pair shoe': 0.13320274240940255,
#  'told': 0.13222331047992164,
#  'issue': 0.12340842311459353,
#  'way': 0.12242899118511263,
#  'say': 0.11263467189030363,
#  'good': 0.11263467189030363,
#  'website': 0.11165523996082272,
#  'paid': 0.11165523996082272,
#  'didn t': 0.10871694417238002,
#  'nothing': 0.10773751224289912,
#  'shipped': 0.10773751224289912,
#  'take': 0.10675808031341821,
#  'send': 0.10381978452497552,
#  'update': 0.10284035259549461,
#  'service': 0.10186092066601371,
#  'package': 0.10088148873653281,
#  'new': 0.09990205680705191,
#  'contact': 0.09990205680705191,
#  'delivery': 0.0969637610186092,
#  'going': 0.0969637610186092,
#  'account': 0.09500489715964741,
#  'response': 0.0940254652301665,
#  've': 0.0930460333006856,
#  'make': 0.0920666013712047,
#  'see': 0.0920666013712047,
#  'need': 0.0910871694417238,
#  'sell': 0.0910871694417238,
#  'purchased': 0.0901077375122429,
#  'know': 0.089128305582762,
#  'im': 0.089128305582762,
#  'receive': 0.089128305582762,
#  'process': 0.089128305582762,
#  'delivered': 0.0881488736532811,
#  'people': 0.0881488736532811,
#  'tried': 0.0871694417238002,
#  'another': 0.0871694417238002,
#  'review': 0.08619000979431929,
#  'really': 0.0842311459353575,
#  'help': 0.0842311459353575,
#  'haven t': 0.0842311459353575,
#  'customer': 0.0832517140058766,
#  'first': 0.0832517140058766,
#  'made': 0.08227228207639568,
#  'someone': 0.08227228207639568,
#  'go': 0.08031341821743389,
#  'sold': 0.08031341821743389,
#  'didnt': 0.08031341821743389,
#  'reply': 0.08031341821743389,
#  'guy': 0.07933398628795299,
#  'right': 0.07933398628795299,
#  'anything': 0.07835455435847209,
#  'took': 0.07835455435847209,
#  'something': 0.07737512242899118,
#  'want': 0.07737512242899118,
#  'fedex': 0.07639569049951028,
#  'first time': 0.07639569049951028,
#  'yet': 0.07541625857002938,
#  'problem': 0.07541625857002938,
#  'thing': 0.07541625857002938,
#  'payment': 0.07541625857002938,
#  'arrived': 0.07443682664054849,
#  'refunded': 0.07443682664054849,
#  'much': 0.07443682664054849,
#  'came': 0.07345739471106758,
#  'give': 0.07247796278158668,
#  'disappointed': 0.07149853085210578,
#  'pay': 0.07051909892262488,
#  'find': 0.07051909892262488,
#  'son': 0.07051909892262488,
#  'place': 0.06953966699314397,
#  'ups': 0.06856023506366307,
#  'fee': 0.06856023506366307,
#  'bid': 0.06856023506366307,
#  'without': 0.06856023506366307,
#  'went': 0.06758080313418217,
#  'ship': 0.06758080313418217,
#  'experience': 0.06758080313418217,
#  'horrible': 0.06758080313418217,
#  'information': 0.06758080313418217,
#  'already': 0.06758080313418217,
#  'never received': 0.06758080313418217,
#  'charged': 0.06660137120470128,
#  'used': 0.06660137120470128,
#  'look': 0.06660137120470128,
#  'bad': 0.06660137120470128,
#  'ordered pair': 0.06660137120470128,
#  'different': 0.06562193927522038,
#  'scam': 0.06464250734573947,
#  'waiting': 0.06366307541625857,
#  'please': 0.06366307541625857,
#  'wait': 0.06268364348677767,
#  'tell': 0.06268364348677767,
#  'lost': 0.06268364348677767,
#  'money back': 0.06268364348677767,
#  'saying': 0.061704211557296766,
#  'trying': 0.061704211557296766,
#  'getting': 0.06072477962781587,
#  'reason': 0.06072477962781587,
#  'claim': 0.06072477962781587,
#  'verified': 0.059745347698334964,
#  'damaged': 0.059745347698334964,
#  'case': 0.059745347698334964,
#  'buying': 0.058765915768854066,
#  'month': 0.05778648383937316,
#  'authentic': 0.05778648383937316,
#  'well': 0.05778648383937316,
#  'many': 0.05680705190989226,
#  'come': 0.05680705190989226,
#  'better': 0.05680705190989226,
#  'everything': 0.05680705190989226,
#  'due': 0.05582761998041136,
#  'won t': 0.05582761998041136,
#  't even': 0.05582761998041136,
#  'jordan': 0.05386875612144956,
#  'terrible': 0.05386875612144956,
#  'try': 0.05386875612144956,
#  'bank': 0.05386875612144956,
#  'wrong size': 0.05386875612144956,
#  'cant': 0.05288932419196866,
#  'sale': 0.05288932419196866,
#  'think': 0.05288932419196866,
#  'great': 0.05190989226248776,
#  'actually': 0.050930460333006855,
#  'picture': 0.050930460333006855,
#  'selling': 0.050930460333006855,
#  'asked': 0.050930460333006855,
#  'support': 0.050930460333006855,
#  'work': 0.050930460333006855,
#  'charge': 0.050930460333006855,
#  'platform': 0.050930460333006855,
#  'long': 0.04995102840352596,
#  'feel': 0.04995102840352596,
#  'authentication': 0.04995102840352596,
#  'ordered shoe': 0.04995102840352596,
#  'two': 0.04897159647404505,
#  'cancelled': 0.04897159647404505,
#  'clearly': 0.04897159647404505,
#  'seem': 0.047992164544564155,
#  'able': 0.04701273261508325,
#  'today': 0.04701273261508325,
#  'put': 0.04603330068560235,
#  'supposed': 0.04603330068560235,
#  'show': 0.04603330068560235,
#  'app': 0.04603330068560235,
#  'arrive': 0.04603330068560235,
#  'keep': 0.04603330068560235,
#  'communication': 0.04505386875612145,
#  'real': 0.04505386875612145,
#  'thank': 0.04505386875612145,
#  'cancel order': 0.04505386875612145,
#  'sure': 0.04407443682664055,
#  'understand': 0.04407443682664055,
#  'use': 0.04407443682664055,
#  'multiple': 0.04407443682664055,
#  'contacted': 0.04407443682664055,
#  're': 0.04407443682664055,
#  'delay': 0.04407443682664055,
#  'happy': 0.043095004897159644,
#  'transaction': 0.043095004897159644,
#  'emailed': 0.043095004897159644,
#  'anyone': 0.043095004897159644,
#  'still haven': 0.043095004897159644}

# %% [markdown]
# # **Topic Modelling**

# %%
reviewData = reviewsDF['text']
tfidf_vectorizer = TfidfVectorizer(stop_words='english', use_idf=True, smooth_idf=True)
reviewData = reviewData.values
document_term_matrix = tfidf_vectorizer.fit_transform(reviewData)

# %%
#Let's consider the top 20 topics
n_topics = 20
lsa_model = TruncatedSVD(n_components=n_topics)
lsa_topic_matrix = lsa_model.fit_transform(document_term_matrix)

# %%
def getCategoriesCounts(lsa_topic_matrix):
  keys = lsa_topic_matrix.argmax(axis=1).tolist()
  count_pairs = Counter(keys).items()
  categories = [pair[0] for pair in count_pairs]
  counts = [pair[1] for pair in count_pairs]
  return (keys,categories, counts)

# %%
lsa_keys, lsa_categories, lsa_counts = getCategoriesCounts(lsa_topic_matrix)

# %%
def get_top_n_words(n, keys, document_term_matrix, tfidf_vectorizer):
    top_indices = []
    for topic in range(n_topics):
        temp_vector_sum = 0
        for i in range(len(keys)):
            if keys[i] == topic:
                temp_vector_sum += document_term_matrix[i]
        if hasattr(temp_vector_sum, 'toarray'):
            temp_vector_sum = temp_vector_sum.toarray()
            top_n_word_indices = np.flip(np.argsort(temp_vector_sum)[0][-n:],0)
            top_indices.append(top_n_word_indices)   
        else:
            top_indices.append([])
    top_words = []
    for topic in top_indices:
        topic_words = []
        for index in topic:
            temp_word_vector = np.zeros((1,document_term_matrix.shape[1]))
            temp_word_vector[:,index] = 1
            the_word = tfidf_vectorizer.inverse_transform(temp_word_vector)[0][0]
            topic_words.append(the_word.encode('ascii').decode('utf-8'))
        top_words.append(" ".join(topic_words))         
    return top_words

# %%
top_n_words_lsa = get_top_n_words(3, lsa_keys, document_term_matrix, tfidf_vectorizer)
for i in range(len(top_n_words_lsa)):
    print("Topic {}: ".format(i+1), top_n_words_lsa[i])
# Out:
# Topic 1:  shoe stockx order
# Topic 2:  order received cancelled
# Topic 3:  long took shipping
# Topic 4:  shoe came received
# Topic 5:  package received fedex
# Topic 6:  size wrong return
# Topic 7:  got package week
# Topic 8:  got order service
# Topic 9:  service customer bad
# Topic 10:  item receive fee
# Topic 11:  fee high price
# Topic 12:  product fake got
# Topic 13:  sneaker didn receive
# Topic 14:  fake dont shoe
# Topic 15:  refund pair money
# Topic 16:  product slow time
# Topic 17:  day seller took
# Topic 18:  return shipping delay
# Topic 19:  way charged expensive
# Topic 20:  good return bought

# %% [markdown]
# We can see the top 20 topics in the whole dataset

# %% [markdown]
# Now let's compare the topics year by year

# %%
reviewsDF.date.describe()
# Out:
# count                    1982
# unique                    188
# top       2022-04-27 00:00:00
# freq                       50
# first     2021-10-22 00:00:00
# last      2022-05-08 00:00:00
# Name: date, dtype: object

# %%
reviewsDF.date.dt.year.value_counts() #to know the years of the available data
# Out:
# 2022    1663
# 2021     319
# Name: date, dtype: int64

# %%
#subset the full dataset into yearly dataframes
reviewsDF2020 = reviewsDF[reviewsDF.date.dt.year==2020]
reviewsDF2021 = reviewsDF[reviewsDF.date.dt.year==2021]
reviewsDF2022 = reviewsDF[reviewsDF.date.dt.year==2022]

# %% [markdown]
# Let's perform LSA to understand the topics for each year

# %%
#2020
reviewData = reviewsDF2020['text']
tfidf_vectorizer = TfidfVectorizer(stop_words='english', use_idf=True, smooth_idf=True)
reviewData = reviewData.values
document_term_matrix = tfidf_vectorizer.fit_transform(reviewData)
#Let's consider the top 2 topics
n_topics = 10
lsa_model = TruncatedSVD(n_components=n_topics)
lsa_topic_matrix = lsa_model.fit_transform(document_term_matrix)
lsa_keys, lsa_categories, lsa_counts = getCategoriesCounts(lsa_topic_matrix)
top_n_words_lsa = get_top_n_words(3, lsa_keys, document_term_matrix, tfidf_vectorizer)
top_2020 = top_n_words_lsa
for i in range(len(top_n_words_lsa)):
    print("Topic {}: ".format(i+1), top_n_words_lsa[i])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/ds/68h8wl896q32r63fbnlht_3c0000gn/T/ipykernel_91832/565364826.py in <module>
#       3 tfidf_vectorizer = TfidfVectorizer(stop_words='english', use_idf=True, smooth_idf=True)
#       4 reviewData = reviewData.values
# ----> 5 document_term_matrix = tfidf_vectorizer.fit_transform(reviewData)
#       6 #Let's consider the top 2 topics
#       7 n_topics = 10
#
# /usr/local/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    2075         """
#    2076         self._check_params()
# -> 2077         X = super().fit_transform(raw_documents)
#    2078         self._tfidf.fit(X)
#    2079         # X is already a transformed view of raw_documents so
#
# /usr/local/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1328                     break
#    1329
# -> 1330         vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1331
#    1332         if self.binary:
#
# /usr/local/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in _count_vocab(self, raw_documents, fixed_vocab)
#    1219             if not vocabulary:
#    1220                 raise ValueError(
# -> 1221                     "empty vocabulary; perhaps the documents only contain stop words"
#    1222                 )
#    1223
#
# ValueError: empty vocabulary; perhaps the documents only contain stop words

# %%
#2021
reviewData = reviewsDF2021['text']
tfidf_vectorizer = TfidfVectorizer(stop_words='english', use_idf=True, smooth_idf=True)
reviewData = reviewData.values
document_term_matrix = tfidf_vectorizer.fit_transform(reviewData)
#Let's consider the top 14 topics
n_topics = 10
lsa_model = TruncatedSVD(n_components=n_topics)
lsa_topic_matrix = lsa_model.fit_transform(document_term_matrix)
lsa_keys, lsa_categories, lsa_counts = getCategoriesCounts(lsa_topic_matrix)
top_n_words_lsa = get_top_n_words(3, lsa_keys, document_term_matrix, tfidf_vectorizer)
top_2021 = top_n_words_lsa
for i in range(len(top_n_words_lsa)):
    print("Topic {}: ".format(i+1), top_n_words_lsa[i])

# %%
#2022
reviewData = reviewsDF2022['text']
tfidf_vectorizer = TfidfVectorizer(stop_words='english', use_idf=True, smooth_idf=True)
reviewData = reviewData.values
document_term_matrix = tfidf_vectorizer.fit_transform(reviewData)
#Let's consider the top 15 topics
n_topics = 10
lsa_model = TruncatedSVD(n_components=n_topics)
lsa_topic_matrix = lsa_model.fit_transform(document_term_matrix)
lsa_keys, lsa_categories, lsa_counts = getCategoriesCounts(lsa_topic_matrix)
top_n_words_lsa = get_top_n_words(3, lsa_keys, document_term_matrix, tfidf_vectorizer)
top_2022 = top_n_words_lsa
for i in range(len(top_n_words_lsa)):
    print("Topic {}: ".format(i+1), top_n_words_lsa[i])

# %% [markdown]
# Visualizing the word cloud for each year to understand the most common words

# %%
#2020

text = " ".join(i for i in reviewsDF2020.text)
wordcloud = WordCloud(stopwords = stopwords, width=800, height=400).generate(text)
fig = plt.figure(1, figsize = (20, 20))
plt.axis('off')
plt.imshow(wordcloud2020)
plt.show()

# %%
#2021

text = " ".join(i for i in reviewsDF2021.text)
wordcloud = WordCloud(stopwords = stopwords, width=800, height=400).generate(text)
fig = plt.figure(1, figsize = (20, 20))
plt.axis('off')
plt.imshow(wordcloud2021)
plt.show()

# %%
#2022

text = " ".join(i for i in reviewsDF2022.text)
wordcloud = WordCloud(stopwords = stopwords, width=800, height=400).generate(text)
fig = plt.figure(1, figsize = (20, 20))
plt.axis('off')
plt.imshow(wordcloud2022)
plt.show()

# %%
#Let's create a df with the top topics for all the years
l1,l5,l6=len(top_2020),len(top_2021),len(top_2022)
max_len = max(l1,l5,l6,l7,l8)

if not max_len == l1:
  top_2020.extend(['-']*(max_len-l1))
if not max_len == l5:
  top_2021.extend(['-']*(max_len-l5))
if not max_len == l6:
  top_2022.extend(['-']*(max_len-l6))

topicsDF = pd.DataFrame({'2020':top_2020,'2021':top_2021,'2022':top_2022})
topicsDF

# %% [markdown]
# Even though we have the top topics for each year, it is difficult to infer how the trend has changed over the years!

# %%
reviewsDF

# %% [markdown]
# As the number of reviews in 2011 is very less, lets plot the polarity for the remaining years in terms of time

# %%
fig, axes = plt.subplots(nrows=2, ncols=2,figsize=(15,10))
#reviewsDF2011.plot.line(x='date',y='polarity',ax=axes[0,0])
reviewsDF2020.plot.line(x='date',y='polarity',ax=axes[0,0],title='2020')
reviewsDF2021.plot.line(x='date',y='polarity',ax=axes[0,1],title='2021')
reviewsDF2022.plot.line(x='date',y='polarity',ax=axes[1,0],title='2022')

# %%
#Let's create a DF with the total number of positive and negative reviews detected for each year
sentimentDF = pd.DataFrame(0,range(5),columns=['Year','pos','neg'])
sentimentDF

# %%
sentimentDF.loc[0] = [2020,reviewsDF2020.Sentiment.value_counts()['pos'],reviewsDF2020.Sentiment.value_counts()['neg']]
sentimentDF.loc[1] = [2021,reviewsDF2021.Sentiment.value_counts()['pos'],reviewsDF2021.Sentiment.value_counts()['neg']]
sentimentDF.loc[2] = [2022,reviewsDF2022.Sentiment.value_counts()['pos'],reviewsDF2022.Sentiment.value_counts()['neg']]

# %%
sentimentDF

# %%
#Plot of positive vs negative reviews over the years
sentimentDF.plot.line(x='Year')

# %% [markdown]
# # **LDA & Topic trend**

# %% [markdown]
# Now, even though the LSA provided the topics, let's analyze the topics using LDA in order to analyze the trend and to better visualize the topics

# %%
df = reviewsDF
df

# %%
warnings.filterwarnings('ignore')

reviews = list(df['text'])
nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])
reviews = pd.Series(reviews).apply(lambda x: x.split())
r1 = []
for wrd in reviews:
  doc = nlp(" ".join(wrd))
  r1.append([token.lemma_ for token in doc if token.pos_ in ['NOUN','ADJ']])

reviewsR1 = r1

# %%
#LDA
dictionary = corpora.Dictionary(reviewsR1)
doc_term_matrix = [dictionary.doc2bow(rev) for rev in reviewsR1]

# %%
# Creating the object for LDA model using gensim library
LDA = gensim.models.ldamodel.LdaModel
# Build LDA model
lda_model = LDA(corpus=doc_term_matrix, id2word=dictionary, num_topics=20, random_state=42,chunksize=1000, passes=50)

# %%
#The top 20 topics that the LDA model has learned are
lda_model.print_topics()

# %%
#Just to check the correctness
lda_model.get_document_topics(doc_term_matrix[1])

# %% [markdown]
# Using the **pyLDAvis** let's visualize the topics and relations

# %%
#Visualizing using the pyLDAvis inbuilt viz
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, doc_term_matrix, dictionary)
vis

# %%
#Let's add a new column in the main df to get the topic number for each review
doc_lda = lda_model[doc_term_matrix]
max_topics = [max(sent, key=lambda x: x[1])[0] for sent in doc_lda]

# %%
dftopic = df
dftopic['topic'] = max_topics

# %%
dftopic

# %%
#the topics for the whole df
dftopic.topic.value_counts()

# %%
#Topic numbers for the year 2020
topic2020 = dftopic[dftopic.date.dt.year==2020]['topic'].value_counts().index.tolist()

# %%
#Topic numbers for the year 2021
topic2021 = dftopic[dftopic.date.dt.year==2021]['topic'].value_counts().index.tolist()

# %%
#Topic numbers for the year 2022
topic2022 = dftopic[dftopic.date.dt.year==2022]['topic'].value_counts().index.tolist()

# %% [markdown]
# The topics learned for each Year

# %%
print("2020 - ",topic2020,"\n2021 - ",topic2021,"\n2022 - ",topic2022)

# %% [markdown]
# The list of all the topics learned with the LDA model

# %%
for i in range(len(lda_model.print_topics())):
  print("Topic:%i" %i ," - ", lda_model.print_topics()[i][1], '\n')

# %% [markdown]
# We can see from above that:
#
# In 2011: There are only 2 topics - Topic #15 and Topic#0

# %%
lda_model.print_topics()[0][1]

# %%
list(set(topic2020).intersection(topic2021))

# %% [markdown]
# From 2011 to 2015 there are two common topics

# %%
list(set(topic2020).intersection(topic2022))

# %% [markdown]
# We can see that from 2015 to 2016 Topic #0 and #15 have been continued, and many more topics have been added

# %%
list(set(topic2021).intersection(topic2022))

# %%
for i in range(20):
  print("Topic:%i" %i )
  print(df[df.topic == i]['rating'].value_counts().index[0])

# %% [markdown]
# we can see that almost all the topics have the highest number of negative reviews except Topic #6 and #3

# %% [markdown]
# From the above learned topics, let's consider one of the most common topic #10 that has been talked about since 2015, which indicates it's one of the most important things people are talking about

# %%
#Let's see some reviews with the topic #10
list(df[df.topic == 10]['text'][:20])

# %%
df[df.topic == 10]['rating'].value_counts()

# %% [markdown]
# We can see from above that most of the reviews are negative, and almost more thatn 75% of the reviews have a 1-star rating. So, we can confirm that this is one of the most important topic people have been talking about over the years.
#
# Similarly we can analyze the rest of the topics depending on the requirement, and how the service wants to be improved, for example if they want to improve the Application, they can see the topic most related to "app" and then do the same analysis as above.
